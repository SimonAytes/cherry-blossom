# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned/combined.csv")

# %%
lat_l = df['lat'].tolist()
long_l = df['long'].tolist()

# %%
vals = []
for a in range(0, len(lat_l)):
    print(f"{lat_l[a]},{long_l[a]}")
# Out:
# 40.6912,-73.963203
# 44.570518,-123.278702
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.931325,9.566175
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# 46.555264,7.373433
# ...

# %%
param_grid_combined = {
    'n_estimators': [50, 100, 200, 150, 250],
    'learning_rate': [0.01, 0.1, 0.2, 0.05, 0.15],
    'max_depth': [3, 4, 5, 2],
    'min_samples_split': [2, 5, 10, 8, 12],
    'min_samples_leaf': [1, 2, 4],
    'subsample': [0.8, 0.9, 1.0, 0.7],
    'max_features': ['auto', 'sqrt', 'log2']
}
# Out:
# ['40.6912,-73.963203',
#  '44.570518,-123.278702',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.931325,9.566175',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
#  '46.555264,7.373433',
# ...

# %%
pd.DataFrame(vals).value_counts()
# Out:
# 47.4814,7.730519           33
# 35.0119831,135.6761135     33
# 38.8853496,-77.0386278     33
# 46.555264,7.373433         23
# 46.931325,9.566175         22
# 35.43972222,139.6525       21
# 45.415,141.6788889         21
# 47.3591,8.590272           20
# 46.143428,8.841697         19
# 34.73929,127.74064          9
# 35.43472222,133.3386111     8
# 24.46666667,123.0105556     7
# 37.27226,126.98533          6
# 40.73082,-73.99733          4
# 49.2237,-123.1636           2
# 44.570518,-123.278702       1
# 34.39587,126.70184          1
# 38.038338,-84.5047          1
# 34.689434,135.269272        1
# 47.837257,-122.215523       1
# 40.6912,-73.963203          1
# dtype: int64
